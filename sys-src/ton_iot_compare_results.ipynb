# %% [markdown]
# # TON-IOT Model Comparison
#
# This notebook:
# 1. Loads **saved inference data**
# 2. Compares **performance and efficiency** across of the inference data
#
# Authors: Raphael Balzer, Kevin Paulus
# GitHub Copilot was used to assist with code

# %%
from pathlib import Path
from ton_iot_utils import load_and_compare_results, print_comparison_summary

# %%
# Check if multiple result files exist
result_dir = Path('inference_results')
if result_dir.exists():
    result_files = list(result_dir.glob('*_inference_*.json'))
    
    if len(result_files) > 1:
        print(f"\n Found {len(result_files)} inference results. Comparing...")
        
        comparison_df = load_and_compare_results(result_files)
        print_comparison_summary(comparison_df)
        
        # Save comparison to CSV
        from datetime import datetime
        comparison_file = result_dir / f"model_comparison_{datetime.now().strftime('%Y%m%d_%H%M%S')}.csv"
        comparison_df.to_csv(comparison_file, index=False)
        print(f"\n Comparison saved to: {comparison_file}")
        
    elif len(result_files) == 1:
        print(f"\nℹ Only one result file found. Run inference on more models to compare.")
    else:
        print(f"\nℹ No previous results found for comparison.")
else:
    print(f"\nℹ No inference_results directory found yet.")
# Out:
#  Found 9 inference results. Comparing...
#
# ====================================================================================================
# MODEL COMPARISON SUMMARY
# ====================================================================================================
#
# ## Performance Metrics ##
#               Model  Accuracy       F1       F2  Precision   Recall
#  catboost_model.pkl  0.998263 0.998862 0.998973   0.998676 0.999048
#   iforest_model.pkl  0.962252 0.975849 0.989857   0.953364 0.999420
# sciforest_model.pkl  0.961525 0.975385 0.989398   0.952892 0.998965
#  fcforest_model.pkl  0.949269 0.967521 0.981020   0.945831 0.990231
# linearsvc_model.pkl  0.951132 0.968591 0.979799   0.950470 0.987416
#       svc_model.pkl  0.763338 0.865749 0.941595   0.763278 1.000000
#  eiforest_model.pkl  0.869697 0.913160 0.903878   0.929061 0.897794
#     ocsvm_model.pkl  0.815207 0.879877 0.884081   0.872958 0.886906
#       sgd_model.pkl  0.557349 0.693939 0.671678   0.734511 0.657615
#
# ## Security Analysis ##
#               Model  Missed_Attacks  False_Alarms
#  catboost_model.pkl              23            32
#   iforest_model.pkl              14          1181
# sciforest_model.pkl              25          1193
#  fcforest_model.pkl             236          1370
# linearsvc_model.pkl             304          1243
#       svc_model.pkl               0          7492
#  eiforest_model.pkl            2469          1656
#     ocsvm_model.pkl            2732          3118
#       sgd_model.pkl            8271          5742
#
# ## Efficiency Metrics ##
#               Model  Inference_Time_s  Throughput_samples/s  Process_Peak_Memory_MB  CPU_Peak  Energy_kWh
#  catboost_model.pkl          5.868784               5394.13                  482.61      19.5    0.000180
#   iforest_model.pkl          1.535825              20612.37                  464.47      15.0    0.000036
# sciforest_model.pkl          1.599565              19791.01                  427.24       0.0    0.000045
#  fcforest_model.pkl          2.058340              15379.87                  449.16       0.0    0.000058
# linearsvc_model.pkl          1.489587              21252.21                  359.84       0.0    0.000030
#       svc_model.pkl        314.126156                100.78                  498.04      47.1    0.011986
#  eiforest_model.pkl          1.639499              19308.94                  398.54       0.0    0.000048
#     ocsvm_model.pkl         23.904763               1324.30                  359.61      31.5    0.000736
#       sgd_model.pkl          1.519390              20835.33                  362.06       0.0    0.000031
#
# ====================================================================================================
#
# BEST MODEL (by F2-Score): catboost_model.pkl
#   F2-Score: 0.9990
#   Recall: 0.9990
#   Missed Attacks: 23
# ====================================================================================================
#
#
#  Comparison saved to: inference_results\model_comparison_20260122_113156.csv
