# %% [markdown]
# Author: Raphael Balzer
# GitHub Copilot was used to assist with code

# %% [markdown]
# ## Isolation Forest

# %%
import sys
sys.path.insert(0, '..')

# %%
# Configuration
CONFIG = {
    'dataset_path': '../data/train_test_network.csv',
    'enable_monitoring': True,
    'random_state': 42
}

print("Configuration:")
for key, value in CONFIG.items():
    print(f"  {key}: {value}")

print("\n  Important: random_state must match training notebook to ensure same test set!")
# Out:
# Configuration:
#   dataset_path: ../data/train_test_network.csv
#   enable_monitoring: True
#   random_state: 42
#
#   Important: random_state must match training notebook to ensure same test set!

# %%
from ton_iot_pipeline import load_and_split_data

X_train, X_val, X_test, y_train, y_val, y_test, _, _, _ = load_and_split_data(
    filepath=CONFIG['dataset_path'],
    random_state=CONFIG['random_state']
)
# Out:
# Loading dataset...
# Dataset shape: (211043, 44)
# Features: ['src_ip', 'src_port', 'dst_ip', 'dst_port', 'proto', 'service', 'duration', 'src_bytes', 'dst_bytes', 'conn_state', 'missed_bytes', 'src_pkts', 'src_ip_bytes', 'dst_pkts', 'dst_ip_bytes', 'dns_query', 'dns_qclass', 'dns_qtype', 'dns_rcode', 'dns_AA', 'dns_RD', 'dns_RA', 'dns_rejected', 'ssl_version', 'ssl_cipher', 'ssl_resumed', 'ssl_established', 'ssl_subject', 'ssl_issuer', 'http_trans_depth', 'http_method', 'http_uri', 'http_version', 'http_request_body_len', 'http_response_body_len', 'http_status_code', 'http_user_agent', 'http_orig_mime_types', 'http_resp_mime_types', 'weird_name', 'weird_addl', 'weird_notice', 'label', 'type']
#
# Data split (stratified by attack type):
#   Train: 147,730 samples (70.0%)
#   Val:   31,656 samples (15.0%)
#   Test:  31,657 samples (15.0%)
#
# Label distribution (0=normal, 1=attack):
#   Train: 76.31% attacks
#   Val:   76.31% attacks
#   Test:  76.31% attacks

# %%
from preprocessing import FancyIFPreprocessor

preprocessor = FancyIFPreprocessor()
X_train = preprocessor.fit_transform(X_train)
# taking only normal data for training
X_train = X_train[y_train == 0]
X_val = preprocessor.transform(X_val)

# %%
X_val_data = X_val.copy()
y_val_data = y_val.copy()

# %%
import matplotlib.pyplot as plt
from sklearn.manifold import TSNE
import numpy as np
# tsne only for numerical features

X_val_numeric = X_val_data.select_dtypes(include=[np.number])

tsne = TSNE(n_components=2, random_state=42)
X_val_2d = tsne.fit_transform(X_val_numeric)
plt.figure(figsize=(10, 6))
plt.scatter(
    X_val_2d[y_val_data == 0, 0], X_val_2d[y_val_data == 0, 1],
    c='#1f77b4', label='Normal', alpha=0.5
)
plt.scatter(
    X_val_2d[y_val_data == 1, 0], X_val_2d[y_val_data == 1, 1],
    c='#d62728', label='Angriff', alpha=0.5
)
plt.legend()
plt.title('t-SNE Projektion von X_val_data')
plt.xlabel('t-SNE Dimension 1')
plt.ylabel('t-SNE Dimension 2')
plt.show()

# %%
import isotree
import numpy as np
from sklearn.metrics import confusion_matrix, classification_report
from preprocessing import plot_score_distribution, plot_confusion_matrix
# David Setup (High-Performance Variante)
iforest = isotree.IsolationForest(
    ndim=1,
    ntrees=100,
    sample_size=2048,
    missing_action="fail",
    coefs="uniform",
    max_depth=8,
    ntry=1,
    scoring_metric="depth",
    random_state=42,
)

iforest.fit(X_train)
scores = iforest.predict(X_val_data)

threshold = np.percentile(scores, 20) 
Y_pred = (scores > threshold).astype(int)

cm = confusion_matrix(y_val_data, Y_pred)
plot_confusion_matrix(cm, "isotree")

scores = iforest.decision_function(X_val_data)
report = classification_report(y_val_data, Y_pred, target_names=['Normal', 'Angriff'])
print("Classification Report:\n", report)
plot_score_distribution(iforest, X_val_data, y_val_data, threshold, "isotree")
# Out:
# c:\Users\rapha\Documents\MAL-ton-iot-ids\.venv\Lib\site-packages\isotree\__init__.py:1737: UserWarning: Instantiating CategoricalDtype without any arguments.Pass a CategoricalDtype instance to silence this warning.
#   X_cat = X.select_dtypes(include = [pd.CategoricalDtype, "object", "bool"])
# c:\Users\rapha\Documents\MAL-ton-iot-ids\.venv\Lib\site-packages\isotree\__init__.py:1757: UserWarning: Instantiating CategoricalDtype without any arguments.Pass a CategoricalDtype instance to silence this warning.
#   self.cols_categ_    = X.select_dtypes(include = [pd.CategoricalDtype, "object", "bool"]).columns.to_numpy(copy=True)
# Classification Report:
#                precision    recall  f1-score   support
#
#       Normal       1.00      0.85      0.92      7500
#      Angriff       0.95      1.00      0.98     24156
#
#     accuracy                           0.96     31656
#    macro avg       0.97      0.92      0.95     31656
# weighted avg       0.96      0.96      0.96     31656

# %%
import isotree
import numpy as np
from sklearn.metrics import confusion_matrix

eiforest = isotree.IsolationForest(
    ndim=2,
    ntrees=100,
    sample_size=2048,
    missing_action="fail",
    max_depth=8,
    ntry=1,
    coefs="uniform",
    standardize_data=False,
    categ_split_type="single_categ",
    scoring_metric="depth",
    random_state=42,
)

eiforest.fit(X_train)
scores = eiforest.predict(X_val_data)

threshold = np.percentile(scores, 20) 
Y_pred = (scores > threshold).astype(int)

cm = confusion_matrix(y_val_data, Y_pred)
plot_confusion_matrix(cm, "isotree")

scores = eiforest.decision_function(X_val_data)
report = classification_report(y_val_data, Y_pred, target_names=['Normal', 'Angriff'])
print("Classification Report:\n", report)
plot_score_distribution(eiforest, X_val_data, y_val_data, threshold, "eiforest")
# Out:
# c:\Users\rapha\Documents\MAL-ton-iot-ids\.venv\Lib\site-packages\isotree\__init__.py:1737: UserWarning: Instantiating CategoricalDtype without any arguments.Pass a CategoricalDtype instance to silence this warning.
#   X_cat = X.select_dtypes(include = [pd.CategoricalDtype, "object", "bool"])
# c:\Users\rapha\Documents\MAL-ton-iot-ids\.venv\Lib\site-packages\isotree\__init__.py:1757: UserWarning: Instantiating CategoricalDtype without any arguments.Pass a CategoricalDtype instance to silence this warning.
#   self.cols_categ_    = X.select_dtypes(include = [pd.CategoricalDtype, "object", "bool"]).columns.to_numpy(copy=True)
# Classification Report:
#                precision    recall  f1-score   support
#
#       Normal       0.70      0.77      0.73      7500
#      Angriff       0.93      0.90      0.91     24156
#
#     accuracy                           0.87     31656
#    macro avg       0.81      0.83      0.82     31656
# weighted avg       0.87      0.87      0.87     31656

# %%
import isotree
import numpy as np
from sklearn.metrics import confusion_matrix

sciforest = isotree.IsolationForest(
    ndim=2,
    ntrees=100,
    sample_size=2048,
    missing_action="fail",
    max_depth=8,
    coefs="normal",
    ntry=10,
    prob_pick_avg_gain=0.9,
    penalize_range=True,
    scoring_metric="depth",
    random_state=42,
)

sciforest.fit(X_train)
scores = sciforest.predict(X_val_data)

threshold = np.percentile(scores, 20) 
Y_pred = (scores > threshold).astype(int)

cm = confusion_matrix(y_val_data, Y_pred)
plot_confusion_matrix(cm, "isotree")

scores = sciforest.decision_function(X_val_data)
report = classification_report(y_val_data, Y_pred, target_names=['Normal', 'Angriff'])
print("Classification Report:\n", report)
plot_score_distribution(sciforest, X_val_data, y_val_data, threshold, "isotree")
# Out:
# c:\Users\rapha\Documents\MAL-ton-iot-ids\.venv\Lib\site-packages\isotree\__init__.py:1737: UserWarning: Instantiating CategoricalDtype without any arguments.Pass a CategoricalDtype instance to silence this warning.
#   X_cat = X.select_dtypes(include = [pd.CategoricalDtype, "object", "bool"])
# c:\Users\rapha\Documents\MAL-ton-iot-ids\.venv\Lib\site-packages\isotree\__init__.py:1757: UserWarning: Instantiating CategoricalDtype without any arguments.Pass a CategoricalDtype instance to silence this warning.
#   self.cols_categ_    = X.select_dtypes(include = [pd.CategoricalDtype, "object", "bool"]).columns.to_numpy(copy=True)
# Classification Report:
#                precision    recall  f1-score   support
#
#       Normal       0.99      0.84      0.91      7500
#      Angriff       0.95      1.00      0.97     24156
#
#     accuracy                           0.96     31656
#    macro avg       0.97      0.92      0.94     31656
# weighted avg       0.96      0.96      0.96     31656

# %%
fcforest = isotree.IsolationForest(
    ndim=2,
    sample_size=2048,
    ntrees=200,
    prob_pick_pooled_gain=0.90,
    penalize_range=False,
    ntry=3,
    coefs="normal",
    missing_action="fail",
    scoring_metric="depth",
    random_state=42
)

fcforest.fit(X_train)
scores = fcforest.predict(X_val_data)

threshold = np.percentile(scores, 20) 
Y_pred = (scores > threshold).astype(int)

cm = confusion_matrix(y_val_data, Y_pred)
plot_confusion_matrix(cm, "isotree")

scores = fcforest.decision_function(X_val_data)
report = classification_report(y_val_data, Y_pred, target_names=['Normal', 'Angriff'])
print("Classification Report:\n", report)
plot_score_distribution(fcforest, X_val_data, y_val_data, threshold, "isotree")
# Out:
# c:\Users\rapha\Documents\MAL-ton-iot-ids\.venv\Lib\site-packages\isotree\__init__.py:1737: UserWarning: Instantiating CategoricalDtype without any arguments.Pass a CategoricalDtype instance to silence this warning.
#   X_cat = X.select_dtypes(include = [pd.CategoricalDtype, "object", "bool"])
# c:\Users\rapha\Documents\MAL-ton-iot-ids\.venv\Lib\site-packages\isotree\__init__.py:1757: UserWarning: Instantiating CategoricalDtype without any arguments.Pass a CategoricalDtype instance to silence this warning.
#   self.cols_categ_    = X.select_dtypes(include = [pd.CategoricalDtype, "object", "bool"]).columns.to_numpy(copy=True)
# Classification Report:
#                precision    recall  f1-score   support
#
#       Normal       0.96      0.81      0.88      7500
#      Angriff       0.94      0.99      0.97     24156
#
#     accuracy                           0.95     31656
#    macro avg       0.95      0.90      0.92     31656
# weighted avg       0.95      0.95      0.94     31656

# %%
from preprocessing import plot_feature_importances

models = {
    'iforest': iforest,
    'eiforest': eiforest,
    'sciforest': sciforest,
    'fcforest': fcforest
}

# Feature-Importances für alle Modelle visualisieren (mit Klassenlabels für bessere Metrik)
importances = plot_feature_importances(models, X_val_data, y_val_data)
# Out:
# Berechne Importances für 4 Modelle (Top 15 Features)...

# %%
from preprocessing import plot_score_distributions_grid

models_for_grid = {
    "iForest": iforest,
    "EIF": eiforest,
    "SCiForest": sciforest,
    "FCF": fcforest,
}

score_thresholds = plot_score_distributions_grid(
    models_for_grid,
    X_val_data,
    y_val_data,
    percentile=20,
    bins=40,
)

# %% [markdown]
# ### save models to pickle files

# %%
import pickle

for key, value in models.items():
    model_name = key
    model = value
    checkpoint = {
        "model": model,
        "preprocessor": preprocessor
    }
    with open(f"../model/{model_name}_model.pkl", "wb") as f:
        pickle.dump(checkpoint, f)
        print(f"Saved model to ../model/{model_name}_model.pkl")
# Out:
# Saved model to ../model/iforest_model.pkl
# Saved model to ../model/eiforest_model.pkl
# Saved model to ../model/sciforest_model.pkl
# Saved model to ../model/fcforest_model.pkl
